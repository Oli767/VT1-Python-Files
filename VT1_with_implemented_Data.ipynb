# %% [markdown]
# ## VT1

# %% [markdown]
# Import Packages

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics as stat

# %% [markdown]
# Definition of Historic Data

# %%
""" Input of Historic Passenger Number Data
Observed Aggregated Demand for System XX"""

Paxnum = []
Data = {
    1982: 8367699,
    1983: 8661582,
    1984: 9102355,
    1985: 9546141,
    1986: 9670366,
    1987: 10534015,
    1988: 11305215,
    1989: 12231671,
    1990: 12769757,
    1991: 12225542,
    1992: 13119273,
    1993: 13574085,
    1994: 14573334,
    1995: 15395406,
    1996: 16276699,
    1997: 18318360,
    1998: 19326589,
    1999: 20925667,
    2000: 22675366,
    2001: 21012871,
    2002: 17948058,
    2003: 17024937,
    2004: 17252906,
    2005: 17884652,
    2006: 19237216,
    2007: 20739113,
    2008: 22099233,
    2009: 21926872,
    2010: 22878251,
    2011: 24337954,
    2012: 24802400,
    2013: 24865138,
    2014: 25477622,
    2015: 26281228,
    2016: 27666428,
    2017: 29396094,
    2018: 31113488,
    2019: 31507692,
    2020: 8341047,
    2021: 10234428,
    2022: 22561132,
}
# print(Data[1986])

# %% [markdown]
# Extracton of Historic Data

# %%
for number in Data.values():
    Paxnum.append(number)
# print(Paxnum)

# %% [markdown]
# Extraction of Annual Change Data

# %%
Annual_change = []
for i in range(1, len(Paxnum)):
    Difference = Paxnum[i] - Paxnum[i - 1]
    Annual_change.append(Difference)
Annual_change = np.array(Annual_change)
# print(Annual_change)

# %% [markdown]
# Extraction of Annual Change in %

# %%
Annual_change_per100 = []
for i in range(1, len(Paxnum)):
    Percent = ((Paxnum[i] / Paxnum[i - 1]) - 1) * 100
    Annual_change_per100.append(Percent)
Annual_change_per100 = np.array(Annual_change_per100)
# print(Annual_change_per100)

# %% [markdown]
# ## Creating Scenarios
# Calculation of Driftrate Mu and Standart Deviation Sigma

# %%
# # Creating Series for Panda
# Series = pd.Series(dictionary["PercentageChange.1"])

# # Calculation of Drift rRate mu (Mean Value of Percentage Change)
# dictionary["mu"] = float(Series.mean())
# mu = dictionary["mu"]

# # Calculation of Standart Deviation sigma
# dictionary["sigma"] = float(Series.std())
# sigma = dictionary["sigma"]

# %% [markdown]
# Creating and Plotting the Forecast with given Values

# %%
# Required Parameters
mu = 0.042754330256447565
sigma = 0.05891802084811409
Dt0 = 22561132
dt = 1
Fth = 50
Forecasts = 20

import Functions as fn

fn.Scenario_plot(fn.Scenario_creation(mu, sigma, Dt0, dt, Fth, Forecasts), Fth)
print(fn.Scenario_creation(mu, sigma, Dt0, dt, Fth, Forecasts))
# Out:
# [[22561132, 22329386.567507558, 23152504.20890766, 24142374.02011909, 25459049.23131801, 27897530.944214497, 30076471.58141219, 32602803.306122493, 34188803.59044816, 36254823.983041234, 39727330.928751335, 42596174.2114364, 46174122.70750084, 49780559.15363341, 52202190.82224293, 56279450.389076486, 59017227.98079682, 58758727.42185148, 59539943.49586925, 63839521.71963445, 66192807.88748825, 69412831.98002253, 71562597.7861866, 70405882.0976348, 71341950.81820443, 78175122.
        40000000.0,
        40000000.0,
        40000000.0,
        40000000.0,
        40000000.0,
        40000000.0,
        50000000.0,
        50000000.0,
        50000000.0,
        50000000.0,
        50000000.0,
        60000000.0,
        60000000.0,
        60000000.0,
        60000000.0,
        60000000.0,
        70000000.0,
        70000000.0,
        70000000.0,
        70000000.0,
        70000000.0,
        80000000.0,
        80000000.0,
        80000000.0,
        80000000.0,
        80000000.0,
        100000000.0,
        100000000.0,
        100000000.0,
        100000000.0,
        100000000.0,
        120000000.0,
        120000000.0,
        120000000.0,
        120000000.0,
        120000000.0,
        140000000.0,
        140000000.0,
        140000000.0,
        140000000.0,
        140000000.0,
    ]
]

fn.Scenario_plot(Capacity_Esimation, 50)

# %% [markdown]
# Calculating the Mean of all Secnarios as a Vector

# %%
# data = np.array(value)
data = np.array(fn.Scenario_creation(mu, sigma, Dt0, dt, Fth, Forecasts))

# Calculate the means for each position using NumPy
meansvalue = np.mean(data, axis=0)

fn.Scenario_plot(data, 50)
# to plot Meansvalue it must be a list
meansvalue = [meansvalue]
fn.Scenario_plot(meansvalue, 50)

# print(meansvalue)

# %% [markdown]
# Creation of a Mean Capacity Vector

# %%
t = np.arange(0, Fth, dt)
deltaK0 = 0  # Capacity change at t=0
K0 = 5  # Capacity at t=0

first_scenario = data[1]
# Choose between Mean or Capacity Estimation
Capacity = np.array(meansvalue)
# Capacity = np.array(Capacity_Esimation)

K = Capacity

first_scenario = np.array(first_scenario)
D = first_scenario

# %% [markdown]
# Input Data for the NPV

# %%
r_D = 0.03  # Revenues per Unit of Demand per Period
r_K = 0.03  # Revenues per Unit of Capacity per Period
co_K = 0.01  # Operational costs per unit of capacity per period
co_D = 0.004  # Operational cost per unit of demand per period
ci_K = 10  # Installation cost per unit of capacity
discount = 0.05  # Discount factor
EoS = 0.85  # EoS factor

# %% [markdown]
# NPV Calculation for the first Scenario

# %%
NPV = fn.NPV_Calculation(D, K, t, r_D, r_K, co_K, co_D, ci_K, discount, EoS)

print(NPV)
# Out:
# 28993033.12232556

# %% [markdown]
# ## Plots
# Specific Plots for Sample Data

# %%
# x = np.arange(1982, 2023)
# y = np.array(Paxnum)
# plt.plot(x, Paxnum)


# plt.plot(x, y, label="Line Plot", color="blue", marker="o")
# plt.grid(True)
# plt.xlabel("Year")
# plt.ylabel("Passenger Numbers")
# plt.title("Demand for Zurich Airport")
# plt.legend()  # Display legend
# plt.figure()


# x2 = x[1:]
# plt.plot(x2, Annual_change, label="Line Plot", color="blue", marker="o")
# plt.grid(True)
# plt.xlabel("Year")
# plt.ylabel("Annual Change of Passenger Numbers")
# plt.title("Demand for Zurich Airport")
# plt.legend()  # Display legend
# plt.figure()

# x2 = x[1:]
# plt.plot(x2, Annual_change_per100, label="Line Plot", color="blue", marker="o")
# plt.grid(True)
# plt.xlabel("Year")
# plt.ylabel("Annual Change of Passenger Numbers in %")
# plt.title("Demand for Zurich Airport")
# plt.legend()  # Display legend
# plt.figure()
